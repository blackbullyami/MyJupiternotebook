# %%
import pandas as pd
import numpy as np
analyse=pd.read_csv('Walmart_Sales.csv')
analyse.head()
analyse.columns
analyse.loc[analyse['Store']==1].count()
# Out:
# Store           143
# Date            143
# Weekly_Sales    143
# Holiday_Flag    143
# Temperature     143
# Fuel_Price      143
# CPI             143
# Unemployment    143
# dtype: int64

# %%
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
x=[1,2,3]
y=[2,3,5]
plt.plot(x,y)

# %%
analyse.info()# To determine the columns and their datatypes
analyse.tail(14)
analyse.head(14)

# %%
analyse['Date'] = pd.to_datetime(analyse['Date'], format='%d-%m-%Y')
analyse.info()
analyse.head(15)
cor=analyse.corr(numeric_only=True)
print (cor)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6435 entries, 0 to 6434
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Store         6435 non-null   int64
#  1   Date          6435 non-null   datetime64[ns]
#  2   Weekly_Sales  6435 non-null   float64
#  3   Holiday_Flag  6435 non-null   int64
#  4   Temperature   6435 non-null   float64
#  5   Fuel_Price    6435 non-null   float64
#  6   CPI           6435 non-null   float64
#  7   Unemployment  6435 non-null   float64
# dtypes: datetime64[ns](1), float64(5), int64(2)
# memory usage: 402.3 KB
#                      Store  Weekly_Sales  Holiday_Flag  Temperature  \
# Store         1.000000e+00     -0.335332 -4.386841e-16    -0.022659
# Weekly_Sales -3.353320e-01      1.000000  3.689097e-02    -0.063810
# Holiday_Flag -4.386841e-16      0.036891  1.000000e+00    -0.155091
# Temperature  -2.265908e-02     -0.063810 -1.550913e-01     1.000000
# ...
